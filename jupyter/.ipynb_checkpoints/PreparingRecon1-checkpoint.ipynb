# %% [markdown]
# # Building Recon1 Model

# %%
using CSV;
using DataFrames;
using MAT;
using Chemostat.Tools;

# %% [markdown]
# ### Model from mat file

# %%
root = "/Users/Pereiro/University/Physic/Research/Jose/Chemostat/ModelsData/Human/Recon1";
storeroot = joinpath(root, "Store");
recon1mat = MAT.matread(joinpath(storeroot, "RECON1.mat"))["RECON1"];

#recon1_mets will contain data linked to any met in the model
@show m = length(recon1mat["mets"][:,1])
mets = DataFrame();
mets[:id] = recon1mat["mets"][:,1];
mets[:y] = zeros(m) # future place for the biomass function coeficient
mets[:e] = zeros(m) # future place for the maintinance demand
mets[:c] = zeros(m) # future place for the medium concentration
mets[:V] = zeros(m) # future place for the uptake ub
mets[:L] = zeros(m) # future place for the uptake lb
mets[:name] = recon1mat["metNames"][:,1];
mets[:formula] = recon1mat["metFormulas"][:,1];
mets[:charge] = recon1mat["metCharge"][:,1];

#recon1_rxns will contain data linked to any reaction in the model
@show n = length(recon1mat["rxns"][:,1])
rxns = DataFrame();
rxns[:id] = recon1mat["rxns"][:,1];
rxns[:lb] = max.(recon1mat["lb"][:,1], -1000) # lb will be modified later
rxns[:ub] = min.(recon1mat["ub"][:,1], 1000) # lb will be modified later 
rxns[:ap] = zeros(n) # future place for the positive costs from shlomi data.
rxns[:an] = zeros(n) # future place for the negative costs from shlomi data.
rxns[:name] = recon1mat["rxnNames"][:,1];
rxns[:rev] = recon1mat["rev"][:,1];
rxns[:subsys] = recon1mat["subSystems"][:,1];

#recon1_s will contain the stoichiometric coeficient matrix of the model
S = sparse(recon1mat["S"]);
Sdf = DataFrame();
Sdf[:i], Sdf[:k], Sdf[:s] = findnz(S);
Sdf[:met] = mets[:id][Sdf[:i]];
Sdf[:rxn] = rxns[:id][Sdf[:k]];

# adding reaction equations
rxns[:eq] = Tools.rxnseqs(rxns[:lb], rxns[:ub], mets[:id], S);
# Out:
# m = length((recon1mat["mets"])[:, 1]) = 2766
# n = length((recon1mat["rxns"])[:, 1]) = 3741

# %% [markdown]
# ### Costs from Shlomi2011

# %%
#cost data from Shlomi2011, kcat units are 1/s and the mw cost are (gDW/mol)
shlomi = CSV.read(joinpath(storeroot, "shlomicosts_recon1compatible.csv"));
C = 0.078 # Shlomi2011. Solvent capacity. Unitless, since this is the mass fraction occupied by enzymes.
# Applying factor of 1000 to convert mol to mmol and 1/3600 to convert s to h.
rxns[:ap] .= ((shlomi[:mws] ./ 1000)./(shlomi[:fkcat] .* 3600))./C; # mw/kcat/C
rxns[:an] .= ((shlomi[:mws] ./ 1000)./(shlomi[:bkcat] .* 3600))./C; # mw/kcat/C
# Out:
# KeyError: key :mws not found
#
# Stacktrace:
#  [1] getindex at ./dict.jl:474 [inlined]
#  [2] getindex(::DataFrames.Index, ::Symbol) at /Users/Pereiro/.julia/v0.6/DataFrames/src/other/index.jl:123
#  [3] getindex(::DataFrames.DataFrame, ::Symbol) at /Users/Pereiro/.julia/v0.6/DataFrames/src/dataframe/dataframe.jl:258
#  [4] include_string(::String, ::String) at ./loading.jl:522

# %%
 (([85300 for i in 1:10] ./ 1000)./ ([25. for i in 1:10] .* 3600)) ./ C
# Out:
# 10-element Array{Float64,1}:
#  0.012151
#  0.012151
#  0.012151
#  0.012151
#  0.012151
#  0.012151
#  0.012151
#  0.012151
#  0.012151
#  0.012151

# %% [markdown]
# ### (IMDM) Medium concentration from Cossio2018

# %%
imdm = CSV.read(joinpath(storeroot, "cossioimdm_recon1compatible.csv"));
mets[:c][imdm[:indx]] .= imdm[:c];
mets[imdm[:indx],:]

# mets with infinite supply
for metid in ["h2o_e", "h_e", "o2_e", "na1_e", "k_e", "cl_e", "so4_e", "fe2_e", "fe3_e"]
    mets[:c][findfirst(mets[:id], metid)] = 999999;
end
# mets[find((c) -> c > 0, mets[:c]),:]

# %% [markdown]
# ### Maintinance demand from Kilburn1969

# %%
atpman = 1.7e-11 # mol ATP/cell/day;
DW = 6.6e-10 #gDW/cell
dm = atpman/DW # mol/gDW/day
dm *= 1e3/24; # mmol/gDW/h bound of DM_atp_c
# just atp hidrolysis
mets[:e][[findfirst(mets[:id],met) for 
        met in ["adp_c", "atp_c", "h2o_c", "h_c", "pi_c"]]] .= dm .* [-1,1,1,-1,-1];

# %% [markdown]
# ### Biomass equation from Shlomi2011

# %%
biomass = CSV.read(joinpath(storeroot, "shlomibiomass_recon1compatible.csv"));
mets[:y][biomass[:indx]] .= biomass[:y];
# mets[biomass[:indx],:]

# %% [markdown]
# ### Exchanges

# %%
# Check this line
for rxni in find((id) -> startswith(id,"EX_"), rxns[:id][Tools.exchanges(S)])
    for meti in Tools.reactsindxs(rxni, S)
        # Cossio's version
#         mets[:V][meti] = 1000; 
#         if rxns[:ub][meti] > 0 || rxns[:ub][meti] == rxns[:lb][meti]
#             mets[:L][meti] = -1000;
#         else
#             mets[:V][meti] = 0; 
#         end
        
        # All metabolite in the medium has L != 0.0 
        if mets[:c][meti] > 0
            mets[:V][meti] = 1000;
            mets[:L][meti] = -1000;
        end
    end
end

# limiting uptake substrate
glc__D_e_V = 0.5; # mmol/gDW/h, Nolan2011, Kiparissides2011
mets[:V][findfirst(mets[:id],"glc__D_e")] = glc__D_e_V; 
# From cossio
for metid in ["arg__L_e", "cys__L_e", "gln__L_e", "his__L_e", "ile__L_e", "leu__L_e", "lys__L_e",
            "met__L_e", "phe__L_e", "thr__L_e", "trp__L_e", "tyr__L_e", "val__L_e",
            "gthrd_e", "btn_e", "fol_e", "inost_e", "ncam_e", "ribflv_e"]
    
    mets[:V][findfirst(mets[:id],metid)] = glc__D_e_V/10;
end

# mets[find((row) -> row[:L] < 0, eachrow(mets)),:]

# %% [markdown]
# ### Turning off internal exchanges and demands

# %%
exchindxs = Tools.exchanges(S)
rxns[:lb][exchindxs] .= 0.0;
rxns[:ub][exchindxs] .= 0.0;
# rxns[exchindxs,:]

# %% [markdown]
# ### Writing!!!

# %%
CSV.write(joinpath(root, "recon1_s.csv"), Sdf);
CSV.write(joinpath(root, "recon1_mets.csv"), mets);
CSV.write(joinpath(root, "recon1_rxns.csv"), rxns);

# %%
shlomicond = CSV.read(joinpath(storeroot,"shlomi2011condenced.csv"));
shlomicond[1] = Int.(shlomicond[1]);
shlomicond[2] = String.(shlomicond[2]);
shlomicond[3] = String.(shlomicond[3]);
shlomicond[4] = Float64.(shlomicond[4]);
shlomicond[5] = Float64.(shlomicond[5]);

# %%
using Plots;
plotly();

# %% [markdown]
# ### kcats

# %%
nonnan = shlomicond[find((kcat) -> !isnan(kcat), shlomicond[4]),4];
subdata = nonnan[find((kcat) ->  0 <= kcat <= 500, nonnan)];
println("Including: $((length(subdata))/(length(nonnan)))%")
println("mode: $(StatsBase.mode(nonnan))");
println("mean: $(StatsBase.mean(nonnan))");
println("median: $(StatsBase.median(nonnan))");
histogram(subdata)
# Out:
# Including: 0.8710562414266118%
# mode: 0.029
# mean: 5035.058011934155
# median: 25.0
# <script src="file:///Users/Pereiro/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="32424533-cdb0-43fd-b7fa-db37af4c18f4" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('32424533-cdb0-43fd-b7fa-db37af4c18f4');
#     Plotly.plot(PLOT, [{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[0.0,0.0,20.0,20.0,0.0,0.0],"showlegend":true,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[347.0,0.0,0.0,347.0,347.0,347.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[20.0,20.0,40.0,40.0,20.0,20.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[56.0,0.0,0.0,56.0,56.0,56.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[40.0,40.0,60.0,60.0,40.0,40.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[44.0,0.0,0.0,44.0,44.0,44.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[60.0,60.0,80.0,80.0,60.0,60.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[44.0,0.0,0.0,44.0,44.0,44.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[80.0,80.0,100.0,100.0,80.0,80.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[10.0,0.0,0.0,10.0,10.0,10.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[100.0,100.0,120.0,120.0,100.0,100.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[26.0,0.0,0.0,26.0,26.0,26.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[120.0,120.0,140.0,140.0,120.0,120.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[36.0,0.0,0.0,36.0,36.0,36.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[140.0,140.0,160.0,160.0,140.0,140.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[11.0,0.0,0.0,11.0,11.0,11.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[160.0,160.0,180.0,180.0,160.0,160.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[5.0,0.0,0.0,5.0,5.0,5.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[180.0,180.0,200.0,200.0,180.0,180.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[8.0,0.0,0.0,8.0,8.0,8.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[200.0,200.0,220.0,220.0,200.0,200.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[9.0,0.0,0.0,9.0,9.0,9.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[220.0,220.0,240.0,240.0,220.0,220.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[4.0,0.0,0.0,4.0,4.0,4.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[240.0,240.0,260.0,260.0,240.0,240.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[2.0,0.0,0.0,2.0,2.0,2.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yax ...

# %% [markdown]
# ### mws

# %%
nonnan = shlomicond[find((mw) -> !isnan(mw), shlomicond[5]),5];
subdata = nonnan[find((mw) ->  0 <= mw <= 1e6, nonnan)];
println("Including: $((length(subdata))/(length(nonnan)))%")
println("mode: $(StatsBase.mode(nonnan))");
println("mean: $(StatsBase.mean(nonnan))");
println("median: $(StatsBase.median(nonnan))");
histogram(subdata)
# Out:
# Including: 0.9934959349593496%
# mode: 24465.0
# mean: 124316.95636856368
# median: 85300.0
# <script src="file:///Users/Pereiro/.julia/v0.6/Plots/src/backends/../../deps/plotly-latest.min.js"></script>    <div id="3fa2ce24-bbf2-46dc-986d-444133fb7c4b" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('3fa2ce24-bbf2-46dc-986d-444133fb7c4b');
#     Plotly.plot(PLOT, [{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[0.0,0.0,20000.0,20000.0,0.0,0.0],"showlegend":true,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[9.0,0.0,0.0,9.0,9.0,9.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[20000.0,20000.0,40000.0,40000.0,20000.0,20000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[222.0,0.0,0.0,222.0,222.0,222.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[40000.0,40000.0,60000.0,60000.0,40000.0,40000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[326.0,0.0,0.0,326.0,326.0,326.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[60000.0,60000.0,80000.0,80000.0,60000.0,60000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[302.0,0.0,0.0,302.0,302.0,302.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[80000.0,80000.0,100000.0,100000.0,80000.0,80000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[295.0,0.0,0.0,295.0,295.0,295.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[100000.0,100000.0,120000.0,120000.0,100000.0,100000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[158.0,0.0,0.0,158.0,158.0,158.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[120000.0,120000.0,140000.0,140000.0,120000.0,120000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[91.0,0.0,0.0,91.0,91.0,91.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[140000.0,140000.0,160000.0,160000.0,140000.0,140000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[128.0,0.0,0.0,128.0,128.0,128.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[160000.0,160000.0,180000.0,180000.0,160000.0,160000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[55.0,0.0,0.0,55.0,55.0,55.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[180000.0,180000.0,200000.0,200000.0,180000.0,180000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[30.0,0.0,0.0,30.0,30.0,30.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[200000.0,200000.0,220000.0,220000.0,200000.0,200000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[43.0,0.0,0.0,43.0,43.0,43.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[220000.0,220000.0,240000.0,240000.0,220000.0,220000.0],"showlegend":false,"mode":"lines","fillcolor":"rgba(0, 154, 250, 1.000)","name":"y1","legendgroup":"y1","line":{"color":"rgba(0, 0, 0, 1.000)","dash":"solid","width":1},"y":[22.0,0.0,0.0,22.0,22.0,22.0],"type":"scatter"},{"xaxis":"x1","fill":"tozeroy","yaxis":"y1","x":[240000.0,240000.0,260000.0,260000.0,240000.0,240000.0 ...

# %% [markdown]
# ### Looking for sinks

# %%
for i in Tools.exchanges(S)
    println(rxns[:id][i]);
    println(rxns[:subsys][i]);
    println(rxns[:eq][i]);
    println();
end
# Out:
# DM_13_cis_oretn_n
# Intracellular demand
# (-1.0) 13_cis_oretn_n ==>
#
# DM_13_cis_retn_n
# Intracellular demand
# (-1.0) 13_cis_retn_n ==>
#
# DM_Asn_X_Ser_Thr_l
# Intracellular demand
# (-1.0) Asn_X_Ser_Thr_l ==>
#
# DM_Ser_Thr_l
# Intracellular demand
# (-1.0) Ser_Thr_l ==>
#
# DM_Ser_Gly_Ala_X_Gly_l
# Intracellular demand
# (-1.0) Ser_Gly_Ala_X_Gly_l ==>
#
# DM_avite1_c
# Intracellular demand
# (-1.0) avite1_c ==>
#
# DM_avite2_c
# Intracellular demand
# (-1.0) avite2_c ==>
#
# DM_bvite_c
# Intracellular demand
# (-1.0) bvite_c ==>
#
# DM_datp_m
# Intracellular demand
# (-1.0) datp_m ==>
#
# DM_datp_n
# Intracellular demand
# (-1.0) datp_n ==>
#
# DM_dctp_m
# Intracellular demand
# (-1.0) dctp_m ==>
#
# DM_dctp_n
# Intracellular demand
# (-1.0) dctp_n ==>
#
# DM_dgtp_m
# Intracellular demand
# (-1.0) dgtp_m ==>
#
# DM_dgtp_n
# Intracellular demand
# (-1.0) dgtp_n ==>
#
# DM_dsT_antigen_g
# Intracellular demand
# (-1.0) dsT_antigen_g ==>
#
# DM_dttp_m
# Intracellular demand
# (-1.0) dttp_m ==>
#
# DM_dttp_n
# Intracellular demand
# (-1.0) dttp_n ==>
#
# DM_ethamp_r
# Intracellular demand
# (-1.0) ethamp_r ==>
#
# DM_gpi_sig_r
# Intracellular demand
# (-1.0) gpi_sig_r ==>
#
# DM_hretn_n
# Intracellular demand
# (-1.0) hretn_n ==>
#
# DM_kdn_c
# Intracellular demand
# (-1.0) kdn_c ==>
#
# DM_melanin_c
# Intracellular demand
# (-1.0) melanin_c ==>
#
# DM_oretn_n
# Intracellular demand
# (-1.0) oretn_n ==>
#
# DM_sTn_antigen_g
# Intracellular demand
# (-1.0) sTn_antigen_g ==>
#
# DM_sprm_c
# Intracellular demand
# (-1.0) sprm_c ==>
#
# DM_yvite_c
# Intracellular demand
# (-1.0) gtocophe_c ==>
#
# EX_10fthf5glu_e
# Extracellular exchange
# (-1.0) 10fthf5glu_e <==>
#
# EX_10fthf6glu_e
# Extracellular exchange
# (-1.0) 10fthf6glu_e <==>
#
# EX_10fthf7glu_e
# Extracellular exchange
# (-1.0) 10fthf7glu_e <==>
#
# EX_10fthf_e
# Extracellular exchange
# (-1.0) 10fthf_e <==>
#
# EX_11_cis_retfa_e
# Extracellular exchange
# (-1.0) 11_cis_retfa_e <==>
#
# EX_13_cis_retnglc_e
# Extracellular exchange
# (-1.0) 13_cis_retnglc_e <==>
#
# EX_1glyc_hs_e
# Extracellular exchange
# (-1.0) 1glyc_hs_e <==>
#
# EX_1mncam_e
# Extracellular exchange
# (-1.0) 1mncam_e <==>
#
# EX_2425dhvitd2_e
# Extracellular exchange
# (-1.0) 2425dhvitd2_e <==>
#
# EX_2425dhvitd3_e
# Extracellular exchange
# (-1.0) 2425dhvitd3_e <==>
#
# EX_24nph_e
# Extracellular exchange
# (-1.0) 24nph_e <==>
#
# EX_25hvitd2_e
# Extracellular exchange
# (-1.0) 25hvitd2_e <==>
#
# EX_25hvitd3_e
# Extracellular exchange
# (-1.0) 25hvitd3_e <==>
#
# EX_2hb_e
# Extracellular exchange
# (-1.0) 2hb_e <==>
#
# EX_2mcit_e
# Extracellular exchange
# (-1.0) 2mcit_e <==>
#
# EX_34dhoxpeg_e
# Extracellular exchange
# (-1.0) 34dhoxpeg_e <==>
#
# EX_34dhphe_e
# Extracellular exchange
# (-1.0) 34dhphe_e <==>
#
# EX_35cgmp_e
# Extracellular exchange
# (-1.0) 35cgmp_e <==>
#
# EX_3aib__D_e
# Extracellular exchange
# (-1.0) 3aib__D_e <==>
#
# EX_3aib_e
# Extracellular exchange
# (-1.0) 3aib_e <==>
#
# EX_3mlda_e
# Extracellular exchange
# (-1.0) 3mlda_e <==>
#
# EX_4abut_e
# Extracellular exchange
# (-1.0) 4abut_e <==>
#
# EX_4hdebrisoquine_e
# Extracellular exchange
# (-1.0) 4hdebrisoquine_e <==>
#
# EX_4hphac_e
# Extracellular exchange
# (-1.0) 4hphac_e <==>
#
# EX_4mtolbutamide_e
# Extracellular exchange
# (-1.0) 4mtolbutamide_e <==>
#
# EX_4nph_e
# Extracellular exchange
# (-1.0) 4nph_e <==>
#
# EX_4nphsf_e
# Extracellular exchange
# (-1.0) 4nphsf_e <==>
#
# EX_4pyrdx_e
# Extracellular exchange
# (-1.0) 4pyrdx_e <==>
#
# EX_5adtststerone_e
# Extracellular exchange
# (-1.0) 5adtststerone_e <==>
#
# EX_5adtststeroneglc_e
# Extracellular exchange
# (-1.0) 5adtststeroneglc_e <==>
#
# EX_5adtststerones_e
# Extracellular exchange
# (-1.0) 5adtststerones_e <==>
#
# EX_5dhf_e
# Extracellular exchange
# (-1.0) 5dhf_e <==>
#
# EX_5fthf_e
# Extracellular exchange
# (-1.0) 5fthf_e <==>
#
# EX_5homeprazole_e
# Extracellular exchange
# (-1.0) 5homeprazole_e <==>
#
# EX_5htrp_e
# Extracellular exchange
# (-1.0) 5htrp_e <==>
#
# EX_5mthf_e
# Extracellular exchange
# (-1.0) 5mthf_e <==>
#
# EX_5thf_e
# Extracellular exchange
# (-1.0) 5thf_e <==>
#
# EX_6dhf_e
# Extracellular exchange
# (-1.0) 6dhf_e <==>
#
# EX_6htststerone_e
# Extracellular exchange
# (-1.0) 6htststerone_e <==>
#
# EX_6thf_e
# Extracellular exchange
# (-1.0) 6thf_e <==>
#
# EX_7dhf_e
# Extracellular exchange
# (-1.0) 7dhf_e <==>
#
# EX_7thf_e
# Extracellular exchange
# (-1.0) 7thf_e <==>
#
# EX_9_cis_retfa_e
# Extracellular exchange
# (-1.0) 9_cis_retfa_e <==>
#
# EX_clpnd_e
# Extracellular exchange
# (-1.0) clpnd_e <==>
#
# EX_cysi__L_e
# Extracellular exchange
# (-1.0) cysi__L_e <==>
#
# EX_Rtotal2_e
# Extracellular exchange
# (-1.0) Rtotal2_e <==>
#
# EX_Rtotal3_e
# Extracellular exchange
# (-1.0) Rtotal3_e <==>
#
# EX_Rtotal_e
# Extracellular exchange
# (-1.0) Rtotal_e <==>
#
# EX_Tyr_ggn_e
# Extracellular exchange
# (-1.0) Tyr_ggn_e <==>
#
# EX_abt_e
# Extracellular exchange
# (-1.0) abt_e <==>
#
# EX_ac_e
# Extracellular exchange
# (-1.0) ac_e <==>
#
# EX_acac_e
# Extracellular exchange
# (-1.0) acac_e <==>
#
# EX_acald_e
# Extracellular exchange
# (-1.0) acald_e <==>
#
# EX_acetone_e
# Extracellular exchange
# (-1.0) acetone_e <==>
#
# EX_acgalfucgalacgalfuc12gal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) acgalfucgalacgalfuc12gal14acglcgalgluside_hs_e <==>
#
# EX_acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) acgalfucgalacgalfucgalacglcgal14acglcgalgluside_hs_e <==>
#
# EX_acgam_e
# Extracellular exchange
# (-1.0) acgam_e <==>
#
# EX_ach_e
# Extracellular exchange
# (-1.0) ach_e <==>
#
# EX_acn13acngalgbside_hs_e
# Extracellular exchange
# (-1.0) acn13acngalgbside_hs_e <==>
#
# EX_acn23acngalgbside_hs_e
# Extracellular exchange
# (-1.0) acn23acngalgbside_hs_e <==>
#
# EX_acnacngal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) acnacngal14acglcgalgluside_hs_e <==>
#
# EX_acnacngalgbside_hs_e
# Extracellular exchange
# (-1.0) acnacngalgbside_hs_e <==>
#
# EX_acngalacglcgal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) acngalacglcgal14acglcgalgluside_hs_e <==>
#
# EX_ade_e
# Extracellular exchange
# (-1.0) ade_e <==>
#
# EX_adn_e
# Extracellular exchange
# (-1.0) adn_e <==>
#
# EX_adp_e
# Extracellular exchange
# (-1.0) adp_e <==>
#
# EX_adprbp_e
# Extracellular exchange
# (-1.0) adprbp_e <==>
#
# EX_adprib_e
# Extracellular exchange
# (-1.0) adprib_e <==>
#
# EX_adrn_e
# Extracellular exchange
# (-1.0) adrn_e <==>
#
# EX_adrnl_e
# Extracellular exchange
# (-1.0) adrnl_e <==>
#
# EX_aflatoxin_e
# Extracellular exchange
# (-1.0) aflatoxin_e <==>
#
# EX_ahandrostanglc_e
# Extracellular exchange
# (-1.0) ahandrostanglc_e <==>
#
# EX_ak2lgchol_hs_e
# Extracellular exchange
# (-1.0) ak2lgchol_hs_e <==>
#
# EX_akg_e
# Extracellular exchange
# (-1.0) akg_e <==>
#
# EX_ala_B_e
# Extracellular exchange
# (-1.0) ala_B_e <==>
#
# EX_ala__D_e
# Extracellular exchange
# (-1.0) ala__D_e <==>
#
# EX_ala__L_e
# Extracellular exchange
# (-1.0) ala__L_e <==>
#
# EX_aldstrn_e
# Extracellular exchange
# (-1.0) aldstrn_e <==>
#
# EX_amp_e
# Extracellular exchange
# (-1.0) amp_e <==>
#
# EX_andrstrn_e
# Extracellular exchange
# (-1.0) andrstrn_e <==>
#
# EX_andrstrnglc_e
# Extracellular exchange
# (-1.0) andrstrnglc_e <==>
#
# EX_antipyrene_e
# Extracellular exchange
# (-1.0) antipyrene_e <==>
#
# EX_apnnox_e
# Extracellular exchange
# (-1.0) apnnox_e <==>
#
# EX_appnn_e
# Extracellular exchange
# (-1.0) appnn_e <==>
#
# EX_aprgstrn_e
# Extracellular exchange
# (-1.0) aprgstrn_e <==>
#
# EX_aqcobal_e
# Extracellular exchange
# (-1.0) aqcobal_e <==>
#
# EX_arab__L_e
# Extracellular exchange
# (-1.0) arab__L_e <==>
#
# EX_arach_e
# Extracellular exchange
# (-1.0) arach_e <==>
#
# EX_arachd_e
# Extracellular exchange
# (-1.0) arachd_e <==>
#
# EX_arg__L_e
# Extracellular exchange
# (-1.0) arg__L_e <==>
#
# EX_ascb__L_e
# Extracellular exchange
# (-1.0) ascb__L_e <==>
#
# EX_asn__L_e
# Extracellular exchange
# (-1.0) asn__L_e <==>
#
# EX_asp__D_e
# Extracellular exchange
# (-1.0) asp__D_e <==>
#
# EX_asp__L_e
# Extracellular exchange
# (-1.0) asp__L_e <==>
#
# EX_atp_e
# Extracellular exchange
# (-1.0) atp_e <==>
#
# EX_avite1_e
# Extracellular exchange
# (-1.0) avite1_e <==>
#
# EX_avite2_e
# Extracellular exchange
# (-1.0) avite2_e <==>
#
# EX_bhb_e
# Extracellular exchange
# (-1.0) bhb_e <==>
#
# EX_bildglcur_e
# Extracellular exchange
# (-1.0) bildglcur_e <==>
#
# EX_bilglcur_e
# Extracellular exchange
# (-1.0) bilglcur_e <==>
#
# EX_bilirub_e
# Extracellular exchange
# (-1.0) bilirub_e <==>
#
# EX_biocyt_e
# Extracellular exchange
# (-1.0) biocyt_e <==>
#
# EX_btn_e
# Extracellular exchange
# (-1.0) btn_e <==>
#
# EX_but_e
# Extracellular exchange
# (-1.0) but_e <==>
#
# EX_bvite_e
# Extracellular exchange
# (-1.0) bvite_e <==>
#
# EX_bz_e
# Extracellular exchange
# (-1.0) bz_e <==>
#
# EX_ca2_e
# Extracellular exchange
# (-1.0) ca2_e <==>
#
# EX_camp_e
# Extracellular exchange
# (-1.0) camp_e <==>
#
# EX_caro_e
# Extracellular exchange
# (-1.0) caro_e <==>
#
# EX_carveol_e
# Extracellular exchange
# (-1.0) carveol_e <==>
#
# EX_cca_d3_e
# Extracellular exchange
# (-1.0) cca_d3_e <==>
#
# EX_cgly_e
# Extracellular exchange
# (-1.0) cgly_e <==>
#
# EX_chol_e
# Extracellular exchange
# (-1.0) chol_e <==>
#
# EX_cholate_e
# Extracellular exchange
# (-1.0) cholate_e <==>
#
# EX_chsterol_e
# Extracellular exchange
# (-1.0) chsterol_e <==>
#
# EX_chtn_e
# Extracellular exchange
# (-1.0) chtn_e <==>
#
# EX_cit_e
# Extracellular exchange
# (-1.0) cit_e <==>
#
# EX_cl_e
# Extracellular exchange
# (-1.0) cl_e <==>
#
# EX_cmp_e
# Extracellular exchange
# (-1.0) cmp_e <==>
#
# EX_co2_e
# Extracellular exchange
# (-1.0) co2_e <==>
#
# EX_co_e
# Extracellular exchange
# (-1.0) co_e <==>
#
# EX_coumarin_e
# Extracellular exchange
# (-1.0) coumarin_e <==>
#
# EX_creat_e
# Extracellular exchange
# (-1.0) creat_e <==>
#
# EX_crmp_hs_e
# Extracellular exchange
# (-1.0) crmp_hs_e <==>
#
# EX_crn_e
# Extracellular exchange
# (-1.0) crn_e <==>
#
# EX_crvnc_e
# Extracellular exchange
# (-1.0) crvnc_e <==>
#
# EX_csn_e
# Extracellular exchange
# (-1.0) csn_e <==>
#
# EX_cspg_a_e
# Extracellular exchange
# (-1.0) cspg_a_e <==>
#
# EX_cspg_b_e
# Extracellular exchange
# (-1.0) cspg_b_e <==>
#
# EX_cspg_c_e
# Extracellular exchange
# (-1.0) cspg_c_e <==>
#
# EX_cspg_d_e
# Extracellular exchange
# (-1.0) cspg_d_e <==>
#
# EX_cspg_e_e
# Extracellular exchange
# (-1.0) cspg_e_e <==>
#
# EX_cyan_e
# Extracellular exchange
# (-1.0) cyan_e <==>
#
# EX_cys__L_e
# Extracellular exchange
# (-1.0) cys__L_e <==>
#
# EX_cytd_e
# Extracellular exchange
# (-1.0) cytd_e <==>
#
# EX_dad_2_e
# Extracellular exchange
# (-1.0) dad_2_e <==>
#
# EX_dad_5_e
# Extracellular exchange
# (-1.0) dad_5_e <==>
#
# EX_dag_hs_e
# Extracellular exchange
# (-1.0) dag_hs_e <==>
#
# EX_dcsptn1_e
# Extracellular exchange
# (-1.0) dcsptn1_e <==>
#
# EX_dcyt_e
# Extracellular exchange
# (-1.0) dcyt_e <==>
#
# EX_debrisoquine_e
# Extracellular exchange
# (-1.0) debrisoquine_e <==>
#
# EX_dgchol_e
# Extracellular exchange
# (-1.0) dgchol_e <==>
#
# EX_dgsn_e
# Extracellular exchange
# (-1.0) dgsn_e <==>
#
# EX_dhdascb_e
# Extracellular exchange
# (-1.0) dhdascb_e <==>
#
# EX_dheas_e
# Extracellular exchange
# (-1.0) dheas_e <==>
#
# EX_dhf_e
# Extracellular exchange
# (-1.0) dhf_e <==>
#
# EX_digalsgalside_hs_e
# Extracellular exchange
# (-1.0) digalsgalside_hs_e <==>
#
# EX_din_e
# Extracellular exchange
# (-1.0) din_e <==>
#
# EX_dlnlcg_e
# Extracellular exchange
# (-1.0) dlnlcg_e <==>
#
# EX_dmantipyrine_e
# Extracellular exchange
# (-1.0) dmantipyrine_e <==>
#
# EX_dmhptcrn_e
# Extracellular exchange
# (-1.0) dmhptcrn_e <==>
#
# EX_dopa_e
# Extracellular exchange
# (-1.0) dopa_e <==>
#
# EX_dopasf_e
# Extracellular exchange
# (-1.0) dopasf_e <==>
#
# EX_drib_e
# Extracellular exchange
# (-1.0) drib_e <==>
#
# EX_duri_e
# Extracellular exchange
# (-1.0) duri_e <==>
#
# EX_eaflatoxin_e
# Extracellular exchange
# (-1.0) eaflatoxin_e <==>
#
# EX_ebastine_e
# Extracellular exchange
# (-1.0) ebastine_e <==>
#
# EX_ebastineoh_e
# Extracellular exchange
# (-1.0) ebastineoh_e <==>
#
# EX_eicostet_e
# Extracellular exchange
# (-1.0) eicostet_e <==>
#
# EX_elaid_e
# Extracellular exchange
# (-1.0) elaid_e <==>
#
# EX_estradiolglc_e
# Extracellular exchange
# (-1.0) estradiolglc_e <==>
#
# EX_estriolglc_e
# Extracellular exchange
# (-1.0) estriolglc_e <==>
#
# EX_estroneglc_e
# Extracellular exchange
# (-1.0) estroneglc_e <==>
#
# EX_estrones_e
# Extracellular exchange
# (-1.0) estrones_e <==>
#
# EX_etoh_e
# Extracellular exchange
# (-1.0) etoh_e <==>
#
# EX_fe2_e
# Extracellular exchange
# (-1.0) fe2_e <==>
#
# EX_fe3_e
# Extracellular exchange
# (-1.0) fe3_e <==>
#
# EX_fol_e
# Extracellular exchange
# (-1.0) fol_e <==>
#
# EX_for_e
# Extracellular exchange
# (-1.0) for_e <==>
#
# EX_fru_e
# Extracellular exchange
# (-1.0) fru_e <==>
#
# EX_fuc13galacglcgal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fuc13galacglcgal14acglcgalgluside_hs_e <==>
#
# EX_fuc14galacglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fuc14galacglcgalgluside_hs_e <==>
#
# EX_fuc__L_e
# Extracellular exchange
# (-1.0) fuc__L_e <==>
#
# EX_fucacgalfucgalacglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucacgalfucgalacglcgalgluside_hs_e <==>
#
# EX_fucacngal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucacngal14acglcgalgluside_hs_e <==>
#
# EX_fucacngalacglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucacngalacglcgalgluside_hs_e <==>
#
# EX_fucfuc12gal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucfuc12gal14acglcgalgluside_hs_e <==>
#
# EX_fucfuc132galacglcgal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucfuc132galacglcgal14acglcgalgluside_hs_e <==>
#
# EX_fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucfucfucgalacglc13galacglcgal14acglcgalgluside_hs_e <==>
#
# EX_fucfucfucgalacglcgal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucfucfucgalacglcgal14acglcgalgluside_hs_e <==>
#
# EX_fucfucgalacglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucfucgalacglcgalgluside_hs_e <==>
#
# EX_fucgal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucgal14acglcgalgluside_hs_e <==>
#
# EX_fucgalfucgalacglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) fucgalfucgalacglcgalgluside_hs_e <==>
#
# EX_fucgalgbside_hs_e
# Extracellular exchange
# (-1.0) fucgalgbside_hs_e <==>
#
# EX_gal_e
# Extracellular exchange
# (-1.0) gal_e <==>
#
# EX_galacglcgalgbside_hs_e
# Extracellular exchange
# (-1.0) galacglcgalgbside_hs_e <==>
#
# EX_galfuc12gal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) galfuc12gal14acglcgalgluside_hs_e <==>
#
# EX_galfucgalacglcgal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) galfucgalacglcgal14acglcgalgluside_hs_e <==>
#
# EX_galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_e
# Extracellular exchange
# (-1.0) galgalfucfucgalacglcgalacglcgal14acglcgalgluside_hs_e <==>
#
# EX_galgalgalthcrm_hs_e
# Extracellular exchange
# (-1.0) galgalgalthcrm_hs_e <==>
#
# EX_gam_e
# Extracellular exchange
# (-1.0) gam_e <==>
#
# EX_gbside_hs_e
# Extracellular exchange
# (-1.0) gbside_hs_e <==>
#
# EX_gchola_e
# Extracellular exchange
# (-1.0) gchola_e <==>
#
# EX_gd1b2_hs_e
# Extracellular exchange
# (-1.0) gd1b2_hs_e <==>
#
# EX_gd1c_hs_e
# Extracellular exchange
# (-1.0) gd1c_hs_e <==>
#
# EX_gdchola_e
# Extracellular exchange
# (-1.0) gdchola_e <==>
#
# EX_gdp_e
# Extracellular exchange
# (-1.0) gdp_e <==>
#
# EX_glc__D_e
# Extracellular exchange
# (-1.0) glc__D_e <==>
#
# EX_gln__L_e
# Extracellular exchange
# (-1.0) gln__L_e <==>
#
# EX_glu__L_e
# Extracellular exchange
# (-1.0) glu__L_e <==>
#
# EX_gluala_e
# Extracellular exchange
# (-1.0) gluala_e <==>
#
# EX_gly_e
# Extracellular exchange
# (-1.0) gly_e <==>
#
# EX_glyb_e
# Extracellular exchange
# (-1.0) glyb_e <==>
#
# EX_glyc_e
# Extracellular exchange
# (-1.0) glyc_e <==>
#
# EX_glyc__S_e
# Extracellular exchange
# (-1.0) glyc__S_e <==>
#
# EX_glygn2_e
# Extracellular exchange
# (-1.0) glygn2_e <==>
#
# EX_glygn4_e
# Extracellular exchange
# (-1.0) glygn4_e <==>
#
# EX_glygn5_e
# Extracellular exchange
# (-1.0) glygn5_e <==>
#
# EX_gmp_e
# Extracellular exchange
# (-1.0) gmp_e <==>
#
# EX_gp1c_hs_e
# Extracellular exchange
# (-1.0) gp1c_hs_e <==>
#
# EX_gp1calpha_hs_e
# Extracellular exchange
# (-1.0) gp1calpha_hs_e <==>
#
# EX_gq1b_hs_e
# Extracellular exchange
# (-1.0) gq1b_hs_e <==>
#
# EX_gq1balpha_hs_e
# Extracellular exchange
# (-1.0) gq1balpha_hs_e <==>
#
# EX_gsn_e
# Extracellular exchange
# (-1.0) gsn_e <==>
#
# EX_gt1a_hs_e
# Extracellular exchange
# (-1.0) gt1a_hs_e <==>
#
# EX_gthox_e
# Extracellular exchange
# (-1.0) gthox_e <==>
#
# EX_gthrd_e
# Extracellular exchange
# (-1.0) gthrd_e <==>
#
# EX_gtp_e
# Extracellular exchange
# (-1.0) gtp_e <==>
#
# EX_gua_e
# Extracellular exchange
# (-1.0) gua_e <==>
#
# EX_h2o2_e
# Extracellular exchange
# (-1.0) h2o2_e <==>
#
# EX_h2o_e
# Extracellular exchange
# (-1.0) h2o_e <==>
#
# EX_h_e
# Extracellular exchange
# (-1.0) h_e <==>
#
# EX_ha_e
# Extracellular exchange
# (-1.0) ha_e <==>
#
# EX_ha_pre1_e
# Extracellular exchange
# (-1.0) ha_pre1_e <==>
#
# EX_hco3_e
# Extracellular exchange
# (-1.0) hco3_e <==>
#
# EX_hcoumarin_e
# Extracellular exchange
# (-1.0) hcoumarin_e <==>
#
# EX_hdca_e
# Extracellular exchange
# (-1.0) hdca_e <==>
#
# EX_hdcea_e
# Extracellular exchange
# WARNING: uuid4(rng) is deprecated, use Compat.UUIDs.uuid4(rng) instead.
# Stacktrace:
#  [1] depwarn(::String, ::Symbol) at ./deprecated.jl:70
#  [2] uuid4(::MersenneTwister) at ./deprecated.jl:57
#  [3] msg_header at /Users/Pereiro/.julia/v0.6/IJulia/src/msg.jl:18 [inlined]
#  [4] msg_pub(::IJulia.Msg, ::String, ::Dict{String,String}, ::Dict{String,Any}) at /Users/Pereiro/.julia/v0.6/IJulia/src/msg.jl:30 (repeats 2 times)
#  [5] send_stream(::String) at /Users/Pereiro/.julia/v0.6/IJulia/src/stdio.jl:172
#  [6] watch_stream(::Base.PipeEndpoint, ::String) at /Users/Pereiro/.julia/v0.6/IJulia/src/stdio.jl:111
#  [7] (::IJulia.##20#22)() at ./task.jl:335
# while loading In[401], in expression starting on line 1
# (-1.0) hdcea_e <==>
#
# EX_hestratriol_e
# Extracellular exchange
# (-1.0) hestratriol_e <==>
#
# EX_hexc_e
# Extracellular exchange
# (-1.0) hexc_e <==>
#
# EX_his__L_e
# Extracellular exchange
# (-1.0) his__L_e <==>
#
# EX_hista_e
# Extracellular exchange
# (-1.0) hista_e <==>
#
# EX_hom__L_e
# Extracellular exchange
# (-1.0) hom__L_e <==>
#
# EX_hpdca_e
# Extracellular exchange
# (-1.0) hpdca_e <==>
#
# EX_hspg_e
# Extracellular exchange
# (-1.0) hspg_e <==>
#
# EX_htaxol_e
# Extracellular exchange
# (-1.0) htaxol_e <==>
#
# EX_hxan_e
# Extracellular exchange
# (-1.0) hxan_e <==>
#
# EX_i_e
# Extracellular exchange
# (-1.0) i_e <==>
#
# EX_idp_e
# Extracellular exchange
# (-1.0) idp_e <==>
#
# EX_ile__L_e
# Extracellular exchange
# (-1.0) ile__L_e <==>
#
# EX_imp_e
# Extracellular exchange
# (-1.0) imp_e <==>
#
# EX_inost_e
# Extracellular exchange
# (-1.0) inost_e <==>
#
# EX_ins_e
# Extracellular exchange
# (-1.0) ins_e <==>
#
# EX_k_e
# Extracellular exchange
# (-1.0) k_e <==>
#
# EX_ksi_e
# Extracellular exchange
# (-1.0) ksi_e <==>
#
# EX_ksi_deg1_e
# Extracellular exchange
# (-1.0) ksi_deg1_e <==>
#
# EX_ksii_core2_e
# Extracellular exchange
# (-1.0) ksii_core2_e <==>
#
# EX_ksii_core4_e
# Extracellular exchange
# (-1.0) ksii_core4_e <==>
#
# EX_lac__D_e
# Extracellular exchange
# (-1.0) lac__D_e <==>
#
# EX_lac__L_e
# Extracellular exchange
# (-1.0) lac__L_e <==>
#
# EX_lcts_e
# Extracellular exchange
# (-1.0) lcts_e <==>
#
# EX_leu__L_e
# Extracellular exchange
# (-1.0) leu__L_e <==>
#
# EX_leuktrC4_e
# Extracellular exchange
# (-1.0) leuktrC4_e <==>
#
# EX_lgnc_e
# Extracellular exchange
# (-1.0) lgnc_e <==>
#
# EX_limnen_e
# Extracellular exchange
# (-1.0) limnen_e <==>
#
# EX_lipoate_e
# Extracellular exchange
# (-1.0) lipoate_e <==>
#
# EX_lneldc_e
# Extracellular exchange
# (-1.0) lneldc_e <==>
#
# EX_lnlc_e
# Extracellular exchange
# (-1.0) lnlc_e <==>
#
# EX_lnlnca_e
# Extracellular exchange
# (-1.0) lnlnca_e <==>
#
# EX_lnlncg_e
# Extracellular exchange
# (-1.0) lnlncg_e <==>
#
# EX_lpchol_hs_e
# Extracellular exchange
# (-1.0) lpchol_hs_e <==>
#
# EX_lys__L_e
# Extracellular exchange
# (-1.0) lys__L_e <==>
#
# EX_mag_hs_e
# Extracellular exchange
# (-1.0) mag_hs_e <==>
#
# EX_malt_e
# Extracellular exchange
# (-1.0) malt_e <==>
#
# EX_malttr_e
# Extracellular exchange
# (-1.0) malttr_e <==>
#
# EX_man_e
# Extracellular exchange
# (-1.0) man_e <==>
#
# EX_meoh_e
# Extracellular exchange
# (-1.0) meoh_e <==>
#
# EX_mepi_e
# Extracellular exchange
# (-1.0) mepi_e <==>
#
# EX_mercplaccys_e
# Extracellular exchange
# (-1.0) mercplaccys_e <==>
#
# EX_met__L_e
# Extracellular exchange
# (-1.0) met__L_e <==>
#
# EX_mthgxl_e
# Extracellular exchange
# (-1.0) mthgxl_e <==>
#
# EX_n2m2nmasn_e
# Extracellular exchange
# (-1.0) n2m2nmasn_e <==>
#
# EX_na1_e
# Extracellular exchange
# (-1.0) na1_e <==>
#
# EX_nac_e
# Extracellular exchange
# (-1.0) nac_e <==>
#
# EX_nad_e
# Extracellular exchange
# (-1.0) nad_e <==>
#
# EX_nadp_e
# Extracellular exchange
# (-1.0) nadp_e <==>
#
# EX_ncam_e
# Extracellular exchange
# (-1.0) ncam_e <==>
#
# EX_nh4_e
# Extracellular exchange
# (-1.0) nh4_e <==>
#
# EX_nifedipine_e
# Extracellular exchange
# (-1.0) nifedipine_e <==>
#
# EX_no_e
# Extracellular exchange
# (-1.0) no_e <==>
#
# EX_npthl_e
# Extracellular exchange
# (-1.0) npthl_e <==>
#
# EX_nrpphr_e
# Extracellular exchange
# (-1.0) nrpphr_e <==>
#
# EX_nrpphrsf_e
# Extracellular exchange
# (-1.0) nrpphrsf_e <==>
#
# EX_nrvnc_e
# Extracellular exchange
# (-1.0) nrvnc_e <==>
#
# EX_o2_e
# Extracellular exchange
# (-1.0) o2_e <==>
#
# EX_o2s_e
# Extracellular exchange
# (-1.0) o2s_e <==>
#
# EX_oagd3_hs_e
# Extracellular exchange
# (-1.0) oagd3_hs_e <==>
#
# EX_oagt3_hs_e
# Extracellular exchange
# (-1.0) oagt3_hs_e <==>
#
# EX_ocdca_e
# Extracellular exchange
# (-1.0) ocdca_e <==>
#
# EX_ocdcea_e
# Extracellular exchange
# (-1.0) ocdcea_e <==>
#
# EX_octa_e
# Extracellular exchange
# (-1.0) octa_e <==>
#
# EX_oh1_e
# Extracellular exchange
# (-1.0) oh1_e <==>
#
# EX_omeprazole_e
# Extracellular exchange
# (-1.0) omeprazole_e <==>
#
# EX_onpthl_e
# Extracellular exchange
# (-1.0) onpthl_e <==>
#
# EX_orn_e
# Extracellular exchange
# (-1.0) orn_e <==>
#
# EX_oxa_e
# Extracellular exchange
# (-1.0) oxa_e <==>
#
# EX_paf_hs_e
# Extracellular exchange
# (-1.0) paf_hs_e <==>
#
# EX_pchol_hs_e
# Extracellular exchange
# (-1.0) pchol_hs_e <==>
#
# EX_pe_hs_e
# Extracellular exchange
# (-1.0) pe_hs_e <==>
#
# EX_peplys_e
# Extracellular exchange
# (-1.0) peplys_e <==>
#
# EX_perillyl_e
# Extracellular exchange
# (-1.0) perillyl_e <==>
#
# EX_pglyc_hs_e
# Extracellular exchange
# (-1.0) pglyc_hs_e <==>
#
# EX_phe__L_e
# Extracellular exchange
# (-1.0) phe__L_e <==>
#
# EX_pheacgln_e
# Extracellular exchange
# (-1.0) pheacgln_e <==>
#
# EX_pheme_e
# Extracellular exchange
# (-1.0) pheme_e <==>
#
# EX_phllqne_e
# Extracellular exchange
# (-1.0) phllqne_e <==>
#
# EX_phyt_e
# Extracellular exchange
# (-1.0) phyt_e <==>
#
# EX_pi_e
# Extracellular exchange
# (-1.0) pi_e <==>
#
# EX_pnto__R_e
# Extracellular exchange
# (-1.0) pnto__R_e <==>
#
# EX_ppa_e
# Extracellular exchange
# (-1.0) ppa_e <==>
#
# EX_pro__D_e
# Extracellular exchange
# (-1.0) pro__D_e <==>
#
# EX_pro__L_e
# Extracellular exchange
# (-1.0) pro__L_e <==>
#
# EX_prostgd2_e
# Extracellular exchange
# (-1.0) prostgd2_e <==>
#
# EX_prostge1_e
# Extracellular exchange
# (-1.0) prostge1_e <==>
#
# EX_prostge2_e
# Extracellular exchange
# (-1.0) prostge2_e <==>
#
# EX_prostgf2_e
# Extracellular exchange
# (-1.0) prostgf2_e <==>
#
# EX_ps_hs_e
# Extracellular exchange
# (-1.0) ps_hs_e <==>
#
# EX_ptdca_e
# Extracellular exchange
# (-1.0) ptdca_e <==>
#
# EX_pydam_e
# Extracellular exchange
# (-1.0) pydam_e <==>
#
# EX_pydx_e
# Extracellular exchange
# (-1.0) pydx_e <==>
#
# EX_pydxn_e
# Extracellular exchange
# (-1.0) pydxn_e <==>
#
# EX_pyr_e
# Extracellular exchange
# (-1.0) pyr_e <==>
#
# EX_rbt_e
# Extracellular exchange
# (-1.0) rbt_e <==>
#
# EX_retfa_e
# Extracellular exchange
# (-1.0) retfa_e <==>
#
# EX_retinol_9_cis_e
# Extracellular exchange
# (-1.0) retinol_9_cis_e <==>
#
# EX_retinol_e
# Extracellular exchange
# (-1.0) retinol_e <==>
#
# EX_retinol_cis_11_e
# Extracellular exchange
# (-1.0) retinol_cis_11_e <==>
#
# EX_retn_e
# Extracellular exchange
# (-1.0) retn_e <==>
#
# EX_retnglc_e
# Extracellular exchange
# (-1.0) retnglc_e <==>
#
# EX_retpalm_e
# Extracellular exchange
# (-1.0) retpalm_e <==>
#
# EX_rib__D_e
# Extracellular exchange
# (-1.0) rib__D_e <==>
#
# EX_ribflv_e
# Extracellular exchange
# (-1.0) ribflv_e <==>
#
# EX_s2l2fn2m2masn_e
# Extracellular exchange
# (-1.0) s2l2fn2m2masn_e <==>
#
# EX_s2l2n2m2masn_e
# Extracellular exchange
# (-1.0) s2l2n2m2masn_e <==>
#
# EX_sarcs_e
# Extracellular exchange
# (-1.0) sarcs_e <==>
#
# EX_sel_e
# Extracellular exchange
# (-1.0) sel_e <==>
#
# EX_ser__D_e
# Extracellular exchange
# (-1.0) ser__D_e <==>
#
# EX_ser__L_e
# Extracellular exchange
# (-1.0) ser__L_e <==>
#
# EX_sl__L_e
# Extracellular exchange
# (-1.0) sl__L_e <==>
#
# EX_so4_e
# Extracellular exchange
# (-1.0) so4_e <==>
#
# EX_spc_hs_e
# Extracellular exchange
# (-1.0) spc_hs_e <==>
#
# EX_sph1p_e
# Extracellular exchange
# (-1.0) sph1p_e <==>
#
# EX_sphs1p_e
# Extracellular exchange
# (-1.0) sphs1p_e <==>
#
# EX_srtn_e
# Extracellular exchange
# (-1.0) srtn_e <==>
#
# EX_strch1_e
# Extracellular exchange
# (-1.0) strch1_e <==>
#
# EX_strch2_e
# Extracellular exchange
# (-1.0) strch2_e <==>
#
# EX_strdnc_e
# Extracellular exchange
# (-1.0) strdnc_e <==>
#
# EX_succ_e
# Extracellular exchange
# (-1.0) succ_e <==>
#
# EX_sucr_e
# Extracellular exchange
# (-1.0) sucr_e <==>
#
# EX_tag_hs_e
# Extracellular exchange
# (-1.0) tag_hs_e <==>
#
# EX_tag__D_e
# Extracellular exchange
# (-1.0) tag__D_e <==>
#
# EX_taur_e
# Extracellular exchange
# (-1.0) taur_e <==>
#
# EX_taxol_e
# Extracellular exchange
# (-1.0) taxol_e <==>
#
# EX_tchola_e
# Extracellular exchange
# (-1.0) tchola_e <==>
#
# EX_tcynt_e
# Extracellular exchange
# (-1.0) tcynt_e <==>
#
# EX_tdchola_e
# Extracellular exchange
# (-1.0) tdchola_e <==>
#
# EX_tethex3_e
# Extracellular exchange
# (-1.0) tethex3_e <==>
#
# EX_tetpent3_e
# Extracellular exchange
# (-1.0) tetpent3_e <==>
#
# EX_tetpent6_e
# Extracellular exchange
# (-1.0) tetpent6_e <==>
#
# EX_tettet6_e
# Extracellular exchange
# (-1.0) tettet6_e <==>
#
# EX_thf_e
# Extracellular exchange
# (-1.0) thf_e <==>
#
# EX_thm_e
# Extracellular exchange
# (-1.0) thm_e <==>
#
# EX_thmmp_e
# Extracellular exchange
# (-1.0) thmmp_e <==>
#
# EX_thmtp_e
# Extracellular exchange
# (-1.0) thmtp_e <==>
#
# EX_thr__L_e
# Extracellular exchange
# (-1.0) thr__L_e <==>
#
# EX_thym_e
# Extracellular exchange
# (-1.0) thym_e <==>
#
# EX_thymd_e
# Extracellular exchange
# (-1.0) thymd_e <==>
#
# EX_thyox__L_e
# Extracellular exchange
# (-1.0) thyox__L_e <==>
#
# EX_tmndnc_e
# Extracellular exchange
# (-1.0) tmndnc_e <==>
#
# EX_tolbutamide_e
# Extracellular exchange
# (-1.0) tolbutamide_e <==>
#
# EX_tre_e
# Extracellular exchange
# (-1.0) tre_e <==>
#
# EX_triodthy_e
# Extracellular exchange
# (-1.0) triodthy_e <==>
#
# EX_triodthysuf_e
# Extracellular exchange
# (-1.0) triodthysuf_e <==>
#
# EX_trp__L_e
# Extracellular exchange
# (-1.0) trp__L_e <==>
#
# EX_tststeroneglc_e
# Extracellular exchange
# (-1.0) tststeroneglc_e <==>
#
# EX_tststerones_e
# Extracellular exchange
# (-1.0) tststerones_e <==>
#
# EX_tsul_e
# Extracellular exchange
# (-1.0) tsul_e <==>
#
# EX_ttdca_e
# Extracellular exchange
# (-1.0) ttdca_e <==>
#
# EX_txa2_e
# Extracellular exchange
# (-1.0) txa2_e <==>
#
# EX_tymsf_e
# Extracellular exchange
# (-1.0) tymsf_e <==>
#
# EX_tyr__L_e
# Extracellular exchange
# (-1.0) tyr__L_e <==>
#
# EX_udp_e
# Extracellular exchange
# (-1.0) udp_e <==>
#
# EX_ump_e
# Extracellular exchange
# (-1.0) ump_e <==>
#
# EX_ura_e
# Extracellular exchange
# (-1.0) ura_e <==>
#
# EX_urate_e
# Extracellular exchange
# (-1.0) urate_e <==>
#
# EX_urea_e
# Extracellular exchange
# (-1.0) urea_e <==>
#
# EX_uri_e
# Extracellular exchange
# (-1.0) uri_e <==>
#
# EX_utp_e
# Extracellular exchange
# (-1.0) utp_e <==>
#
# EX_vacc_e
# Extracellular exchange
# (-1.0) vacc_e <==>
#
# EX_val__L_e
# Extracellular exchange
# (-1.0) val__L_e <==>
#
# EX_vitd2_e
# Extracellular exchange
# (-1.0) vitd2_e <==>
#
# EX_vitd3_e
# Extracellular exchange
# (-1.0) vitd3_e <==>
#
# EX_whddca_e
# Extracellular exchange
# (-1.0) whddca_e <==>
#
# EX_whhdca_e
# Extracellular exchange
# (-1.0) whhdca_e <==>
#
# EX_whtststerone_e
# Extracellular exchange
# (-1.0) whtststerone_e <==>
#
# EX_whttdca_e
# Extracellular exchange
# (-1.0) whttdca_e <==>
#
# EX_xolest2_hs_e
# Extracellular exchange
# (-1.0) xolest2_hs_e <==>
#
# EX_xolest_hs_e
# Extracellular exchange
# (-1.0) xolest_hs_e <==>
#
# EX_xoltri24_e
# Extracellular exchange
# (-1.0) xoltri24_e <==>
#
# EX_xoltri25_e
# Extracellular exchange
# (-1.0) xoltri25_e <==>
#
# EX_xoltri27_e
# Extracellular exchange
# (-1.0) xoltri27_e <==>
#
# EX_xyl__D_e
# Extracellular exchange
# (-1.0) xyl__D_e <==>
#
# EX_xylt_e
# Extracellular exchange
# (-1.0) xylt_e <==>
#
# EX_yvite_e
# Extracellular exchange
# (-1.0) gtocophe_e <==>
